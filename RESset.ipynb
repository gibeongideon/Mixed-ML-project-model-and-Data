# %%
import numpy as np
import pandas as pd

# %%
dfR= pd.read_csv('/home/gsociety/Desktop/The Model/STORAGE/resultDataRR.csv')

# %%
dfR.head()

dfR['TEAMS']=pd.Series([x.upper() for x in dfR.TEAMS])

#split TEAMS into HOME & AWAY 
#df['HOME']=pd.Series([x.split()[1] for x in df.TEAMS])
#df['AWAY']=pd.Series([x.split()[3] for x in df.TEAMS])

# %%
def teamCode(S):
    
    cats=['MADRID', 'AMSTERDAM','BERLIN','LONDON','ROME','OSLO','LISBON','PARIS','BRUSSELS','ATHENS','STOCKHOLM',
          'COPENHAGEN','VIENNA', 'ANKARA','EDINBURGH','BERN']

    catsRev=[]
    for tm in S:
        if tm == cats[0]:
            catsRev.append(1)
        elif tm == cats[1]:
            catsRev.append(2)
        elif tm == cats[2]:
            catsRev.append(3)
        elif tm == cats[3]:
            catsRev.append(4)
        elif tm == cats[4]:
            catsRev.append(5)
        elif tm == cats[5]:
            catsRev.append(6)
        elif tm == cats[6]:
            catsRev.append(7)
        elif tm == cats[7]:
            catsRev.append(8)
        elif tm == cats[8]:
            catsRev.append(9)
        elif tm == cats[9]:
            catsRev.append(10)
        elif tm == cats[10]:
            catsRev.append(11)
        elif tm == cats[11]:
            catsRev.append(12)
        elif tm == cats[12]:
            catsRev.append(13)
        elif tm == cats[13]:
            catsRev.append(14)
        elif tm == cats[14]:
            catsRev.append(15)
        elif tm == cats[15]:
            catsRev.append(16)
    return catsRev

# %%
dfR['TEAMS']

#split TEAMS into HOME & AWAY 
dfR['HOME']=pd.Series([x.split()[1] for x in dfR.TEAMS])
dfR['AWAY']=pd.Series([x.split()[4] for x in dfR.TEAMS])
dfR['TIMED']=pd.Series([x.split()[1] for x in dfR.TIMER])
#Use teamCode FX to code HOME & AWAY collumns and crean new HOMECODE & AWAYCODE
#for t in dfR['HOME']:
dfR['AWAY']

dfR['HOMECODE']=teamCode(dfR['HOME'])
dfR['AWAYCODE']=teamCode(dfR['AWAY'])
#dfR['CODESUM']=teamCode(dfR['HOME']) + teamCode(dfR['AWAY'])
#teamCode(dfR['HOME'])

colum=['TEAMS', 'HOME','AWAY', 'HOMECODE', 'AWAYCODE', 'HTR', 'FTR', 'TIMER','TIMED']
dfR1 = dfR.reindex(columns=colum).fillna(0)#.values
# split into input (X) and output (Y) variables
dfR1
# Out:
#                                  TEAMS        HOME        AWAY  HOMECODE  \
# 0        VFL COPENHAGEN  -  VFL LONDON  COPENHAGEN      LONDON        12
# 1            VFL LISBON  -  VFL BERLIN      LISBON      BERLIN         7
# 2              VFL VIENNA  -  VFL OSLO      VIENNA        OSLO        13
# 3         VFL AMSTERDAM  -  VFL ANKARA   AMSTERDAM      ANKARA         2
# 4              VFL ATHENS  -  VFL ROME      ATHENS        ROME        10
# 5         VFL STOCKHOLM  -  VFL MADRID   STOCKHOLM      MADRID        11
# 6           VFL BRUSSELS  -  VFL PARIS    BRUSSELS       PARIS         9
# 7           VFL BERN  -  VFL EDINBURGH        BERN   EDINBURGH        16
# 8          VFL BERLIN  -  VFL BRUSSELS      BERLIN    BRUSSELS         3
# 9               VFL PARIS  -  VFL BERN       PARIS        BERN         8
# 10        VFL LONDON  -  VFL STOCKHOLM      LONDON   STOCKHOLM         4
# 11         VFL ROME  -  VFL COPENHAGEN        ROME  COPENHAGEN         5
# ...

# %%
dfR['TEAMS'].head()

#split TEAMS into HOME & AWAY 
dfR['HOME']=pd.Series([x.split()[1] for x in dfR.TEAMS])
dfR['AWAY']=pd.Series([x.split()[3] for x in dfR.TEAMS])
#Use teamCode FX to code HOME & AWAY collumns and crean new HOMECODE & AWAYCODE
#dfR['HOMECODE']=teamCode(dfR['HOME'])
#dfR['AWAYCODE']=teamCode(dfR['AWAY'])


#colum=['TEAMS', 'HOME','AWAY', 'HOMECODE', 'AWAYCODE',
#'1', '2', 'X', 'HT1', 'HT2', 'HTX', 'FS (0:0)', 'FS(0:0)2', 'FS(0:0)X',
      #  'G(0.5)O', 'G(0.5)U', 'G(1.5)O', 'G(1.5)U', 'G(2.5)O',
     #  'G(2.5)U', 'G(3.5)O', 'G(3.5)U', 'G(4.5)O', 'G(4.5)U']
dataR=dfR.fillna(0)#.values
# split into input (X) and output (Y) variables
