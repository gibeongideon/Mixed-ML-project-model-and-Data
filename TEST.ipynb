# %%
import numpy as np
import pandas as pd
csv_data = pd.read_csv('liveData200.csv')

# %%
def teamCode(S):
    
    cats=['MADRID', 'AMSTERDAM','BERLIN','LONDON','ROME','OSLO','LISBON','PARIS','BRUSSELS','ATHENS','STOCKHOLM',
          'COPENHAGEN','VIENNA', 'ANKARA','EDINBURGH','BERN']
    catsRev=[]
    for tm in S:
        if tm == cats[0]:
            catsRev.append(1)
        elif tm == cats[1]:
            catsRev.append(2)
        elif tm == cats[2]:
            catsRev.append(3)
        elif tm == cats[3]:
            catsRev.append(4)
        elif tm == cats[4]:
            catsRev.append(5)
        elif tm == cats[5]:
            catsRev.append(6)
        elif tm == cats[6]:
            catsRev.append(7)
        elif tm == cats[7]:
            catsRev.append(8)
        elif tm == cats[8]:
            catsRev.append(9)
        elif tm == cats[9]:
            catsRev.append(10)
        elif tm == cats[10]:
            catsRev.append(11)
        elif tm == cats[11]:
            catsRev.append(12)
        elif tm == cats[12]:
            catsRev.append(13)
        elif tm == cats[13]:
            catsRev.append(14)
        elif tm == cats[14]:
            catsRev.append(15)
        elif tm == cats[15]:
            catsRev.append(16)
    return catsRev

       
catsRev 
csv_data['TEAMS']=catsRev
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-51a1ba8a89a8> in <module>()
#      42
#      43
# ---> 44 catsRev
#      45 csv_data['TEAMS']=catsRev
#
# NameError: name 'catsRev' is not defined

# %%
csv_data.T
# Out:
#                            0                          1    \
# 1                          2.4                       1.45
# 2                         2.65                       6.75
# X                          3.9                       4.55
# HT1                       2.85                        1.8
# HT2                        3.1                          6
# HTX                       2.45                        2.8
# FS (0:0)                   1.9                        1.4
# FS(0:0)2                   1.9                        3.2
# FS(0:0)X                    23                         17
# TEAMS     VFL OSLO  VFL MADRID  VFL BERLIN  VFL STOCKHOLM
# G(0.5)O                      0                          0
# G(0.5)U                      0                          0
# G(1.5)O                      0                       1.18
# G(1.5)U                      0                       4.25
# G(2.5)O                    1.6                       1.65
# G(2.5)U                    2.2                       2.15
# G(3.5)O                   2.65                        2.5
# G(3.5)U                    1.4                       1.45
# G(4.5)O                    4.3                          0
# G(4.5)U                   1.18                          0
# TEST                         0                          0
#
#                                  2                     3    \
# 1                               2.05                  5.25
# 2                                3.9                   1.7
# X                               3.25                  3.75
# HT1                              2.6                     5
# HT2                              4.6                  2.05
# HTX                              2.1                  2.55
# FS (0:0)                        1.75                  3.55
# FS(0:0)2                        2.95                   1.4
# FS(0:0)X                           6                 10.25
# TEAMS     VFL COPENHAGEN  VFL VIENNA  VFL BERN  VFL LISBON
# G(0.5)O                         1.14                     0
# G(0.5)U                            6                     0
# G(1.5)O                         1.75                  1.35
# G(1.5)U                         1.95                  2.95
# G(2.5)O                         3.05                   2.2
# G(2.5)U                         1.35                   1.6
# G(3.5)O                            0                  4.05
# G(3.5)U                            0                   1.2
# G(4.5)O                            0                     0
# G(4.5)U                            0                     0
# TEST                               1                     1
#
#                               4                          5    \
# 1                            3.55                        3.6
# 2                             1.9                       2.05
# X                            4.25                       3.55
# HT1                           4.4                       3.95
# HT2                          2.15                       2.45
# HTX                          2.55                       2.35
# FS (0:0)                      2.6                       2.45
# FS(0:0)2                     1.55                        1.7
# FS(0:0)X                       21                       11.5
# TEAMS     VFL EDINBURGH  VFL ROME  VFL ATHENS  VFL AMSTERDAM
# G(0.5)O                         0                          0
# G(0.5)U                         0                          0
# G(1.5)O                      1.18                       1.35
# G(1.5)U                      4.25                        2.9
# G(2.5)O                       1.6                       2.15
# G(2.5)U                       2.2                       1.65
# G(3.5)O                      2.55                       3.95
# G(3.5)U                      1.45                        1.2
# G(4.5)O                         0                          0
# G(4.5)U                         0                          0
# TEST                            1                          0
#
#                                6                      7    \
# 1                             1.75                   1.65
# 2                             5.25                    4.4
# X                             3.45                    4.6
# HT1                           2.15                   2.05
# HT2                           5.75                      5
# HTX                           2.25                   2.55
# FS (0:0)                       1.6                   1.45
# FS(0:0)2                      2.85                      3
# FS(0:0)X                      9.75                   14.5
# TEAMS     VFL LONDON  VFL BRUSSELS  VFL PARIS  VFL ANKARA
# G(0.5)O                          0                      0
# G(0.5)U                          0                      0
# G(1.5)O                       1.35                   1.25
# G(1.5)U                        2.9                   3.65
# G(2.5)O                       2.15                   1.65
# G(2.5)U                        1.6                   2.15
# G(3.5)O                          4                    3.1
# G(3.5)U                        1.2                    1.3
# G(4.5)O                          0                      0
# G(4.5)U                          0                      0
# TEST                             0                      0
#
#                            8                          9    \
# 1                          2.4                       1.45
# 2                         2.65                       6.75
# X                          3.9                       4.55
# HT1                       2.85                        1.8
# HT2                        3.1                          6
# HTX                       2.45                        2.8
# FS (0:0)                   1.9                        1.4
# FS(0:0)2                   1.9                        3.2
# FS(0:0)X                    23                         17
# TEAMS     VFL OSLO  VFL MADRID  VFL BERLIN  VFL STOCKHOLM
# G(0.5)O                      0                          0
# G(0.5)U                      0                          0
# G(1.5)O                      0                       1.18
# G(1.5)U                      0                       4.25
# G(2.5)O                    1.6                       1.65
# G(2.5)U                    2.2                       2.15
# G(3.5)O                   2.65                        2.5
# G(3.5)U                    1.4                       1.45
# G(4.5)O                    4.3                          0
# G(4.5)U                   1.18                          0
# TEST                         0                          1
#
#                    ...                                 342  \
# 1                  ...                                1.75
# 2                  ...                                5.25
# X                  ...                                3.45
# HT1                ...                                2.15
# HT2                ...                                5.75
# HTX                ...                                2.25
# FS (0:0)           ...                                 1.6
# FS(0:0)2           ...                                2.85
# FS(0:0)X           ...                                9.75
# TEAMS              ...            VFL LONDON  VFL BRUSSELS
# G(0.5)O            ...                                   0
# G(0.5)U            ...                                   0
# G(1.5)O            ...                                1.35
# G(1.5)U            ...                                 2.9
# G(2.5)O            ...                                2.15
# G(2.5)U            ...                                 1.6
# G(3.5)O            ...                                   4
# G(3.5)U            ...                                 1.2
# G(4.5)O            ...                                   0
# G(4.5)U            ...                                   0
# TEST               ...                                   0
#
#                             343                      344  \
# 1                          1.65                      2.9
# 2                           4.4                        2
# X                           4.6                     4.85
# HT1                        2.05                      3.9
# HT2                           5                      2.4
# HTX                        2.55                      2.5
# FS (0:0)                   1.45                      2.4
# FS(0:0)2                      3                     1.65
# FS(0:0)X                   14.5                    19.25
# TEAMS     VFL PARIS  VFL ANKARA  VFL BERN  VFL STOCKHOLM
# G(0.5)O                       0                        0
# G(0.5)U                       0                        0
# G(1.5)O                    1.25                     1.25
# G(1.5)U                    3.65                      3.5
# G(2.5)O                    1.65                      1.8
# G(2.5)U                    2.15                      1.9
# G(3.5)O                     3.1                     3.15
# G(3.5)U                     1.3                      1.3
# G(4.5)O                       0                        0
# G(4.5)U                       0                        0
# TEST                          0                        0
#
#                            345                   346                    347  \
# 1                         1.65                  2.25                   3.65
# 2                          5.5                  2.95                      2
# X                         3.75                   3.7                   3.55
# HT1                        1.9                   2.6                    4.2
# HT2                       5.75                   3.1                   2.25
# HTX                        2.6                   2.7                    2.5
# FS (0:0)                   1.5                   1.7                   2.55
# FS(0:0)2                  2.85                   2.1                   1.65
# FS(0:0)X                    14                    41                     11
# TEAMS     VFL OSLO  VFL ATHENS  VFL ROME  VFL LONDON  VFL PARIS  VFL BERLIN
# G(0.5)O                      0                     0                      0
# G(0.5)U                      0                     0                      0
# G(1.5)O                    1.3                     0                    1.3
# G(1.5)U                    3.3                     0                    3.2
# G(2.5)O                   1.95                   1.5                   1.85
# G(2.5)U                   1.75                  2.35                   1.85
# G(3.5)O                   3.25                   2.3                    3.2
# G(3.5)U                    1.3                  1.55                    1.3
# G(4.5)O                      0                   4.1                      0
# G(4.5)U                      0                   1.2                      0
# TEST                         1                     1                      1
#
#                                 348                       349  \
# 1                              2.55                      1.75
# 2                               2.7                         6
# X                               3.5                      3.25
# HT1                            3.05                       2.3
# HT2                            3.25                         6
# HTX                            2.25                       2.1
# FS (0:0)                       1.95                      1.55
# FS(0:0)2                       2.05                       3.6
# FS(0:0)X                      11.25                      6.75
# TEAMS     VFL LISBON  VFL AMSTERDAM  VFL BRUSSELS  VFL VIENNA
# G(0.5)O                           0                      1.12
# G(0.5)U                           0                      6.75
# G(1.5)O                         1.4                       1.6
# G(1.5)U                         2.7                       2.2
# G(2.5)O                        2.35                       2.8
# G(2.5)U                        1.55                       1.4
# G(3.5)O                         4.5                         0
# G(3.5)U                        1.16                         0
# G(4.5)O                           0                         0
# G(4.5)U                           0                         0
# TEST                              0                         0
#
#                                     350                     351
# 1                                  2.35                    5.25
# 2                                   3.1                     1.6
# X                                   3.3                    4.25
# HT1                                 2.9                     5.5
# HT2                                3.65                    1.85
# HTX                                 2.2                     2.8
# FS (0:0)                           1.95                     3.1
# FS(0:0)2                           2.15                     1.4
# FS(0:0)X                           9.75                      19
# TEAMS     VFL EDINBURGH  VFL COPENHAGEN  VFL ANKARA  VFL MADRID
# G(0.5)O                               0                       0
# G(0.5)U                               0                       0
# G(1.5)O                            1.45                    1.18
# G(1.5)U                            2.65                     4.3
# G(2.5)O                            2.45                    1.55
# G(2.5)U                             1.5                    2.25
# G(3.5)O                             4.8                    2.65
# G(3.5)U                            1.15                    1.45
# G(4.5)O                               0                       0
# G(4.5)U                               0                       0
# TEST                                  1                       1
#
# [21 rows x 352 columns]

# %%
df=csv_data
with open('/home/gsociety/Desktop/The Model/liveDataQ.csv', 'a') as f:
            df.to_csv(f, index=False, header=False)

# %%
#from keras.models import Sequential
#from keras.layers import Dense
#from keras.layers import LSTM
#from numpy import array
from keras.models import load_model
from __future__ import print_function
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation
from keras.optimizers import Adam
from keras.callbacks import TensorBoard
#from keras.utils import np_utils
from __future__ import division, print_function
from keras.callbacks import ModelCheckpoint
import os
import numpy as np
np.random.seed(1671) # for reproducibility



# network and training tunes
NB_EPOCH = 2
BATCH_SIZE = 4
VERBOSE = 1
#NB_CLASSES = 10 # number of outputs = number of digits
OPTIMIZER = Adam() # optimizer, explained later in this chapter
N_HIDDEN = 32
N_HIDDEN2 = 8
VALIDATION_SPLIT=0.2 # how much TRAIN is reserved for VALIDATION
DROPOUT = 0.3
IN_SHAPE = 20
MODEL_DIR = "/tmp"




#DATA________________________________________________________________________
    
dataset = np.loadtxt("liveDataQ.csv", delimiter=",")
# split into input (X) and output (Y) variables
x=dataset[:,0:20]
y= dataset[:,20]
X= (x.astype('float32'))/30
Y= y.astype('float32')

#MODEL_______________________________________________________________________

model = Sequential()
model.add(Dense(N_HIDDEN, input_shape=(IN_SHAPE,)))
model.add(Activation('relu'))
model.add(Dropout(DROPOUT))
model.add(Dense(N_HIDDEN2))
model.add(Activation('relu'))
model.add(Dropout(DROPOUT))
model.add(Dense(1))
model.add(Activation('sigmoid'))
#model.add(Dense(1, activation='linear'))
#model.summary()

#LOSS OPT
#model.compile(loss='mse', optimizer='adam',metrics=['accuracy'])
model.compile(loss='binary_crossentropy',optimizer=OPTIMIZER,metrics=['accuracy'])
checkpoint = ModelCheckpoint(filepath=os.path.join(MODEL_DIR, "model-{epoch:02d}.h5"),save_best_only=True)
#TRAINING
model.fit(X, Y,batch_size=BATCH_SIZE, epochs=NB_EPOCH,
          verbose=VERBOSE, validation_split=VALIDATION_SPLIT,callbacks=[checkpoint])
#TETS SCORE
score = model.evaluate(X, Y, verbose=VERBOSE)
print("Test score:", score[0])
print('Test accuracy:', score[1])
print('Training done')
#MODEL SAVE
model.save('/home/gsociety/Desktop/The Model/M_Drafts/V_model.h5')
#print('Model Saved')

#keras.callbacks.TensorBoard(log_dir='./logs', histogram_freq=0, write_graph=True, write_images=False)
# Out:
# Using TensorFlow backend.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-6a42e4afd945> in <module>()
#      36 #DATA________________________________________________________________________
#      37
# ---> 38 dataset = np.loadtxt("liveDataQ.csv", delimiter=",")
#      39 # split into input (X) and output (Y) variables
#      40 x=dataset[:,0:20]
#
# ~/anaconda3/envs/Keras/lib/python3.5/site-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin)
#    1022
#    1023             # Convert each value according to its column and store
# -> 1024             items = [conv(val) for (conv, val) in zip(converters, vals)]
#    1025             # Then pack it according to the dtype's nesting
#    1026             items = pack_items(items, packing)
#
# ~/anaconda3/envs/Keras/lib/python3.5/site-packages/numpy/lib/npyio.py in <listcomp>(.0)
#    1022
#    1023             # Convert each value according to its column and store
# -> 1024             items = [conv(val) for (conv, val) in zip(converters, vals)]
#    1025             # Then pack it according to the dtype's nesting
#    1026             items = pack_items(items, packing)
#
# ~/anaconda3/envs/Keras/lib/python3.5/site-packages/numpy/lib/npyio.py in floatconv(x)
#     723         if b'0x' in x:
#     724             return float.fromhex(asstr(x))
# --> 725         return float(x)
#     726
#     727     typ = dtype.type
#
# ValueError: could not convert string to float: b'VFL OSLO  VFL MADRID'
